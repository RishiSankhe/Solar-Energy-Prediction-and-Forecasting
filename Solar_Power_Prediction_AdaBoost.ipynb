# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.ensemble import AdaBoostRegressor, AdaBoostClassifier
import xgboost as xgb

# %%
df = pd.read_csv('Pasion et al dataset.csv')

# %%
# Encode location data
df_with_location_en = pd.get_dummies(df, columns=['Location'], drop_first=True)

# Encode season data
df_with_loc_season_en = pd.get_dummies(df_with_location_en, columns=['Season'], drop_first=True)

min_hour_of_interest = 10
max_hour_of_interest = 15

df_with_loc_season_en['delta_hr']= df_with_loc_season_en.Hour - min_hour_of_interest

# Create Cyclic date features
df_with_loc_season_en['sine_mon']= np.sin((df_with_loc_season_en.Month - 1)*np.pi/11)
df_with_loc_season_en['cos_mon']= np.cos((df_with_loc_season_en.Month - 1)*np.pi/11)
df_with_loc_season_en['sine_hr']= np.sin((df_with_loc_season_en.delta_hr*np.pi/(max_hour_of_interest - min_hour_of_interest)))
df_with_loc_season_en['cos_hr']= np.cos((df_with_loc_season_en.delta_hr*np.pi/(max_hour_of_interest - min_hour_of_interest)))

# %%
selected_columns = ['Latitude', 'Humidity', 'AmbientTemp', 'PolyPwr', 'Wind.Speed',
                     'Visibility', 'Pressure', 'Cloud.Ceiling', 'Location_Grissom',
                     'Location_Hill Weber', 'Location_JDMT', 'Location_Kahului',
                     'Location_MNANG', 'Location_Malmstrom', 'Location_March AFB',
                     'Location_Offutt', 'Location_Peterson', 'Location_Travis',
                     'Location_USAFA','Season_Spring', 'Season_Summer', 'Season_Winter',
                     'sine_mon', 'cos_mon', 'sine_hr', 'cos_hr']

# %%
df_processed = df_with_loc_season_en[selected_columns].reset_index(drop=True)

# %%
target_label = 'PolyPwr'

# %%
input_feat = list(set(selected_columns).difference(set([target_label])))

# %%
df_X = df_processed[input_feat].reset_index(drop=True)

# %%
df_y = df_processed[target_label]

# %%
X_train, X_test, y_train, y_test = train_test_split(df_X, df_y, test_size=0.2, random_state=42)

# %%
base_estimator = DecisionTreeClassifier()

# %%
#Create lists for hyperparameter tuning

loss_list = ['linear', 'exponential', 'square']
n_estimators_list = [int(x) for x in np.linspace(start = 100, stop = 2000, num = 20)]          # Number of boosting rounds
learning_rate_list = np.linspace(0.01, 0.3, 100)
base_estimator_list =  [None, DecisionTreeClassifier(max_depth=1), DecisionTreeClassifier(max_depth=3)]
algorithm_list = ['SAMME','SAMME.R']

# %%
ada_grid = {
    'n_estimators': n_estimators_list,
    'learning_rate': learning_rate_list,
    'loss': loss_list,
    'estimator': base_estimator_list
                }

# %%
ada_base = AdaBoostRegressor()

# %%
ada_base.get_params()
# Out:
# {'base_estimator': 'deprecated',
#  'estimator': None,
#  'learning_rate': 1.0,
#  'loss': 'linear',
#  'n_estimators': 50,
#  'random_state': None}

# %%
ada_random = RandomizedSearchCV(estimator=ada_base, param_distributions=ada_grid, 
                                 n_iter=1000, cv=4, verbose=2, random_state=42, 
                                 n_jobs=-1)

# %%
ada_random.fit(X_train,y_train)
# Out:
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.08030303030303029, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.06272727272727271, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.2531313131313131, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.07737373737373736, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.07737373737373736, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1623232323232323, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1623232323232323, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.19747474747474747, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.19747474747474747, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.19747474747474747, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.19747474747474747, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.2502020202020202, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.2502020202020202, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.2502020202020202, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.2502020202020202, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.024646464646464646, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.024646464646464646, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.024646464646464646, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.024646464646464646, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.15353535353535352, n_estimators=1700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.15353535353535352, n_estimators=1700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.15353535353535352, n_estimators=1700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.15353535353535352, n_estimators=1700; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.15353535353535352, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.15353535353535352, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.15353535353535352, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.15353535353535352, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.16818181818181818, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.16818181818181818, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.16818181818181818, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.16818181818181818, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2736363636363636, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2736363636363636, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2736363636363636, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2736363636363636, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.11838383838383837, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.11838383838383837, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.11838383838383837, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.11838383838383837, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.19747474747474747, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.19747474747474747, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.19747474747474747, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.19747474747474747, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.24434343434343433, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.24434343434343433, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.24434343434343433, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.24434343434343433, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2824242424242424, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2824242424242424, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2824242424242424, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2824242424242424, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.0715151515151515, n_estimators=1000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.0715151515151515, n_estimators=1000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.0715151515151515, n_estimators=1000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.0715151515151515, n_estimators=1000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.01292929292929293, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.01292929292929293, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.01292929292929293, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.01292929292929293, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.11252525252525251, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.11252525252525251, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.11252525252525251, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.11252525252525251, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.01292929292929293, n_estimators=1000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.01292929292929293, n_estimators=1000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.01292929292929293, n_estimators=1000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.01292929292929293, n_estimators=1000; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.26484848484848483, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.26484848484848483, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.26484848484848483, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.26484848484848483, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.25606060606060604, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.25606060606060604, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.25606060606060604, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.25606060606060604, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.17404040404040405, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.17404040404040405, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.17404040404040405, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.17404040404040405, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.16525252525252526, n_estimators=500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.16525252525252526, n_estimators=500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.16525252525252526, n_estimators=500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.16525252525252526, n_estimators=500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.27656565656565657, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.27656565656565657, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.27656565656565657, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.27656565656565657, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.27656565656565657, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.27656565656565657, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.27656565656565657, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.27656565656565657, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.06272727272727271, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.06272727272727271, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.06272727272727271, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.06272727272727271, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.19747474747474747, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.19747474747474747, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.19747474747474747, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.19747474747474747, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.18575757575757576, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.18575757575757576, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.18575757575757576, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.18575757575757576, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.2912121212121212, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.2912121212121212, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.2912121212121212, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.2912121212121212, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.28535353535353536, n_estimators=1000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.28535353535353536, n_estimators=1000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.28535353535353536, n_estimators=1000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.28535353535353536, n_estimators=1000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.20919191919191918, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.20919191919191918, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.20919191919191918, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.20919191919191918, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.08909090909090908, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.08909090909090908, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.08909090909090908, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.08909090909090908, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1828282828282828, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1828282828282828, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1828282828282828, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1828282828282828, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.1623232323232323, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.1623232323232323, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.1623232323232323, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.1623232323232323, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.12717171717171716, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.12717171717171716, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.12717171717171716, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.12717171717171716, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.05686868686868687, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.05686868686868687, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.05686868686868687, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.05686868686868687, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.1301010101010101, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.1301010101010101, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.1301010101010101, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.1301010101010101, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.021717171717171718, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.021717171717171718, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.021717171717171718, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.021717171717171718, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.21505050505050505, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.21505050505050505, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.21505050505050505, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.21505050505050505, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.23848484848484847, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.23848484848484847, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.23848484848484847, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.23848484848484847, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1828282828282828, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1828282828282828, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1828282828282828, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1828282828282828, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2736363636363636, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2736363636363636, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2736363636363636, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2736363636363636, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.16818181818181818, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.16818181818181818, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.16818181818181818, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.16818181818181818, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.21505050505050505, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.21505050505050505, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.21505050505050505, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.21505050505050505, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.24727272727272726, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.24727272727272726, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.24727272727272726, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.24727272727272726, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1623232323232323, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1623232323232323, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1623232323232323, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1623232323232323, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.258989898989899, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.258989898989899, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.258989898989899, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.258989898989899, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.21505050505050505, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.21505050505050505, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.21505050505050505, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.21505050505050505, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2707070707070707, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2707070707070707, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2707070707070707, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2707070707070707, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.2004040404040404, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.2004040404040404, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.2004040404040404, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.2004040404040404, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.20919191919191918, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.20919191919191918, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.20919191919191918, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.20919191919191918, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.06272727272727271, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.06272727272727271, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.06272727272727271, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.06272727272727271, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.015858585858585857, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.015858585858585857, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.015858585858585857, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.015858585858585857, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.2531313131313131, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.2531313131313131, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.2531313131313131, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.2531313131313131, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.021717171717171718, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.021717171717171718, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.021717171717171718, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.021717171717171718, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.2736363636363636, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.2736363636363636, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.2736363636363636, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.2736363636363636, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.04515151515151515, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.04515151515151515, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.04515151515151515, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.04515151515151515, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.059797979797979794, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.059797979797979794, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.059797979797979794, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.059797979797979794, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.06272727272727271, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.06272727272727271, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.06272727272727271, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.06272727272727271, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.08909090909090908, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.08909090909090908, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.08909090909090908, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.08909090909090908, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.16818181818181818, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.16818181818181818, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.16818181818181818, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.16818181818181818, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.2209090909090909, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.2209090909090909, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.2209090909090909, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.2209090909090909, n_estimators=1800; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.23848484848484847, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.23848484848484847, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.23848484848484847, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.23848484848484847, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1593939393939394, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1593939393939394, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1593939393939394, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1593939393939394, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.10666666666666666, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.10666666666666666, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.10666666666666666, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.10666666666666666, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.26484848484848483, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.26484848484848483, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.26484848484848483, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.26484848484848483, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.015858585858585857, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.015858585858585857, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.015858585858585857, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.015858585858585857, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.018787878787878787, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.018787878787878787, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.018787878787878787, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.018787878787878787, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.01292929292929293, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.01292929292929293, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.01292929292929293, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.01292929292929293, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.06565656565656565, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.06565656565656565, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.06565656565656565, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.06565656565656565, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.024646464646464646, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.024646464646464646, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.024646464646464646, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.024646464646464646, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1301010101010101, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1301010101010101, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1301010101010101, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1301010101010101, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.14181818181818182, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.14181818181818182, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.14181818181818182, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.14181818181818182, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.27949494949494946, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.27949494949494946, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.27949494949494946, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.27949494949494946, n_estimators=600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.021717171717171718, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.021717171717171718, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.021717171717171718, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.021717171717171718, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1301010101010101, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1301010101010101, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1301010101010101, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.1301010101010101, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.2502020202020202, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.2502020202020202, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.2502020202020202, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.2502020202020202, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.01292929292929293, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.01292929292929293, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.01292929292929293, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.01292929292929293, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.042222222222222223, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.042222222222222223, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.042222222222222223, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.042222222222222223, n_estimators=800; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.19747474747474747, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.19747474747474747, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.19747474747474747, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.19747474747474747, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.08323232323232323, n_estimators=500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.08323232323232323, n_estimators=500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.08323232323232323, n_estimators=500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.08323232323232323, n_estimators=500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1798989898989899, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1798989898989899, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1798989898989899, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1798989898989899, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.2707070707070707, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.2707070707070707, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.2707070707070707, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.2707070707070707, n_estimators=1200; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.21212121212121213, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.21212121212121213, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.21212121212121213, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.21212121212121213, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1798989898989899, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1798989898989899, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1798989898989899, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1798989898989899, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.24727272727272726, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.24727272727272726, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.24727272727272726, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.24727272727272726, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.19747474747474747, n_estimators=200; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.19747474747474747, n_estimators=200; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.19747474747474747, n_estimators=200; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.19747474747474747, n_estimators=200; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.21505050505050505, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.21505050505050505, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.21505050505050505, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.21505050505050505, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.09202020202020202, n_estimators=500; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.09202020202020202, n_estimators=500; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.09202020202020202, n_estimators=500; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.09202020202020202, n_estimators=500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.13303030303030303, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.13303030303030303, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.13303030303030303, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.13303030303030303, n_estimators=900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.06858585858585858, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.06858585858585858, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.06858585858585858, n_estimators=700; total time=   0.0s
# ...
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.26484848484848483, n_estimators=1600; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.13303030303030303, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.13303030303030303, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.13303030303030303, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.13303030303030303, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.2707070707070707, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.2707070707070707, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.2707070707070707, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.2707070707070707, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1916161616161616, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1916161616161616, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1916161616161616, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.1916161616161616, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.13595959595959595, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.13595959595959595, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.13595959595959595, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.13595959595959595, n_estimators=2000; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.15353535353535352, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.15353535353535352, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.15353535353535352, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.15353535353535352, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.17404040404040405, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.17404040404040405, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.17404040404040405, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.17404040404040405, n_estimators=1100; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.13303030303030303, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.13303030303030303, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.13303030303030303, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.13303030303030303, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.030505050505050507, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.030505050505050507, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.030505050505050507, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.030505050505050507, n_estimators=700; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.018787878787878787, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.018787878787878787, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.018787878787878787, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.018787878787878787, n_estimators=400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.21505050505050505, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.21505050505050505, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.21505050505050505, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.21505050505050505, n_estimators=1300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.07444444444444444, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.07444444444444444, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.07444444444444444, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.07444444444444444, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.1388888888888889, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.1388888888888889, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.1388888888888889, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=DecisionTreeClassifier(max_depth=1), learning_rate=0.1388888888888889, n_estimators=1900; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2736363636363636, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2736363636363636, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2736363636363636, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.2736363636363636, n_estimators=100; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.13595959595959595, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.13595959595959595, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.13595959595959595, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=None, learning_rate=0.13595959595959595, n_estimators=300; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.24434343434343433, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.24434343434343433, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.24434343434343433, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME, estimator=DecisionTreeClassifier(max_depth=3), learning_rate=0.24434343434343433, n_estimators=1400; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.26484848484848483, n_estimators=1500; total time=   0.0s
# [CV] END algorithm=SAMME.R, estimator=None, learning_rate=0.26484848484848483, n_estimators=1500; total time=   0.0s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 ada_random.fit(X_train,y_train)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:1806, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1804 def _run_search(self, evaluate_candidates):
#    1805     """Search n_iter candidates from param_distributions"""
# -> 1806     evaluate_candidates(
#    1807         ParameterSampler(
#    1808             self.param_distributions, self.n_iter, random_state=self.random_state
#    1809         )
#    1810     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     868 elif len(out) != n_candidates * n_splits:
#     869     raise ValueError(
#     870         "cv.split and cv.get_n_splits returned "
#     871         "inconsistent results. Expected {} "
#     872         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     873     )
# --> 875 _warn_or_raise_about_fit_failures(out, self.error_score)
#     877 # For callable self.scoring, the return type is only know after
#     878 # calling. If the return type is a dictionary, the error scores
#     879 # can now be inserted with the correct key. The type checking
#     880 # of out will be done in `_insert_error_scores`.
#     881 if callable(self.scoring):
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:414, in _warn_or_raise_about_fit_failures(results, error_score)
#     407 if num_failed_fits == num_fits:
#     408     all_fits_failed_message = (
#     409         f"\nAll the {num_fits} fits failed.\n"
#     410         "It is very likely that your model is misconfigured.\n"
#     411         "You can try to debug the error by setting error_score='raise'.\n\n"
#     412         f"Below are more details about the failures:\n{fit_errors_summary}"
#     413     )
# --> 414     raise ValueError(all_fits_failed_message)
#     416 else:
#     417     some_fits_failed_message = (
#     418         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     419         "The score on these train-test partitions for these parameters"
#    (...)
#     423         f"Below are more details about the failures:\n{fit_errors_summary}"
#     424     )
#
# ValueError:
# All the 4000 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2072 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py", line 171, in fit
#     sample_weight, estimator_weight, estimator_error = self._boost(
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py", line 582, in _boost
#     return self._boost_discrete(iboost, X, y, sample_weight, random_state)
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py", line 647, in _boost_discrete
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/tree/_classes.py", line 959, in fit
#     super()._fit(
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/tree/_classes.py", line 284, in _fit
#     check_classification_targets(y)
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/utils/multiclass.py", line 215, in check_classification_targets
#     raise ValueError(
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.
#
# --------------------------------------------------------------------------------
# 1928 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py", line 171, in fit
#     sample_weight, estimator_weight, estimator_error = self._boost(
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py", line 579, in _boost
#     return self._boost_real(iboost, X, y, sample_weight, random_state)
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py", line 588, in _boost_real
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/tree/_classes.py", line 959, in fit
#     super()._fit(
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/tree/_classes.py", line 284, in _fit
#     check_classification_targets(y)
#   File "/Users/rishisankhe/Library/Python/3.9/lib/python/site-packages/sklearn/utils/multiclass.py", line 215, in check_classification_targets
#     raise ValueError(
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(ada_random.predict(X_test), y_test))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 from sklearn.metrics import mean_squared_error
# ----> 2 np.sqrt(mean_squared_error(ada_random.predict(X_test), y_test))
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:518, in BaseSearchCV.predict(self, X)
#     499 @available_if(_estimator_has("predict"))
#     500 def predict(self, X):
#     501     """Call predict on the estimator with the best found parameters.
#     502
#     503     Only available if ``refit=True`` and the underlying estimator supports
#    (...)
#     516         the best found parameters.
#     517     """
# --> 518     check_is_fitted(self)
#     519     return self.best_estimator_.predict(X)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1462, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1459     raise TypeError("%s is not an estimator instance." % (estimator))
#    1461 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1462     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This RandomizedSearchCV instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
ada_random.best_params_
# Out:
# {'n_estimators': 100,
#  'loss': 'exponential',
#  'learning_rate': 0.05686868686868687,
#  'estimator': None}
