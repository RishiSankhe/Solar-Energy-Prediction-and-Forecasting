# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

df = pd.read_csv('Pasion et al dataset.csv')
data = df[df['Location'] == 'Hill Weber']
data = df[df['Time'] == 1000]

data = data[['Date', 'PolyPwr']] 
data.rename(columns={'Date': 'ds', 'PolyPwr': 'y'}, inplace=True)

data['ds'] = pd.to_datetime(data['ds'])
data.set_index('ds', inplace=True)

scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

look_back = 20  
X, y = [], []
for i in range(len(data_scaled) - look_back):
    X.append(data_scaled[i:i+look_back])
    y.append(data_scaled[i+look_back])

X, y = np.array(X), np.array(y)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

model = RandomForestRegressor(n_estimators=100, max_depth=3, random_state=42)
model.fit(X_train.reshape(X_train.shape[0], -1), y_train.reshape(-1))

predictions = model.predict(X_test.reshape(X_test.shape[0], -1))
predictions = scaler.inverse_transform(predictions.reshape(-1, 1))
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")

last_observed = X_test[-1].reshape(1, -1)
forecast_value = model.predict(last_observed)
forecast_value = scaler.inverse_transform(forecast_value.reshape(-1, 1))[0][0]
print(f"Forecast for PolyPwr (Yn+1): {forecast_value:.2f}")
# Out:
# Root Mean Squared Error (RMSE): 3.36
# Forecast for PolyPwr (Yn+1): 7.81

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

df = pd.read_csv('Pasion et al dataset.csv')
data = df[df['Location'] == 'Hill Weber']
data = df[df['Time'] == 1100]

data = data[['Date', 'PolyPwr']] 
data.rename(columns={'Date': 'ds', 'PolyPwr': 'y'}, inplace=True)

data['ds'] = pd.to_datetime(data['ds'])
data.set_index('ds', inplace=True)

scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

look_back = 20  
X, y = [], []
for i in range(len(data_scaled) - look_back):
    X.append(data_scaled[i:i+look_back])
    y.append(data_scaled[i+look_back])

X, y = np.array(X), np.array(y)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

model = RandomForestRegressor(n_estimators=100, max_depth=3, random_state=42)
model.fit(X_train.reshape(X_train.shape[0], -1), y_train.reshape(-1))

predictions = model.predict(X_test.reshape(X_test.shape[0], -1))
predictions = scaler.inverse_transform(predictions.reshape(-1, 1))
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")

last_observed = X_test[-1].reshape(1, -1)
forecast_value = model.predict(last_observed)
forecast_value = scaler.inverse_transform(forecast_value.reshape(-1, 1))[0][0]
print(f"Forecast for PolyPwr (Yn+1): {forecast_value:.2f}")
# Out:
# Root Mean Squared Error (RMSE): 3.99
# Forecast for PolyPwr (Yn+1): 11.22

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

df = pd.read_csv('Pasion et al dataset.csv')
data = df[df['Location'] == 'Hill Weber']
data = df[df['Time'] == 1200]

data = data[['Date', 'PolyPwr']] 
data.rename(columns={'Date': 'ds', 'PolyPwr': 'y'}, inplace=True)

data['ds'] = pd.to_datetime(data['ds'])
data.set_index('ds', inplace=True)

scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

look_back = 20  
X, y = [], []
for i in range(len(data_scaled) - look_back):
    X.append(data_scaled[i:i+look_back])
    y.append(data_scaled[i+look_back])

X, y = np.array(X), np.array(y)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

model = RandomForestRegressor(n_estimators=100, max_depth=3, random_state=42)
model.fit(X_train.reshape(X_train.shape[0], -1), y_train.reshape(-1))

predictions = model.predict(X_test.reshape(X_test.shape[0], -1))
predictions = scaler.inverse_transform(predictions.reshape(-1, 1))
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")

last_observed = X_test[-1].reshape(1, -1)
forecast_value = model.predict(last_observed)
forecast_value = scaler.inverse_transform(forecast_value.reshape(-1, 1))[0][0]
print(f"Forecast for PolyPwr (Yn+1): {forecast_value:.2f}")
# Out:
# Root Mean Squared Error (RMSE): 4.69
# Forecast for PolyPwr (Yn+1): 14.88

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

df = pd.read_csv('Pasion et al dataset.csv')
data = df[df['Location'] == 'Hill Weber']
data = df[df['Time'] == 1300]

data = data[['Date', 'PolyPwr']] 
data.rename(columns={'Date': 'ds', 'PolyPwr': 'y'}, inplace=True)

data['ds'] = pd.to_datetime(data['ds'])
data.set_index('ds', inplace=True)

scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

look_back = 20  
X, y = [], []
for i in range(len(data_scaled) - look_back):
    X.append(data_scaled[i:i+look_back])
    y.append(data_scaled[i+look_back])

X, y = np.array(X), np.array(y)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

model = RandomForestRegressor(n_estimators=100, max_depth=3, random_state=42)
model.fit(X_train.reshape(X_train.shape[0], -1), y_train.reshape(-1))

predictions = model.predict(X_test.reshape(X_test.shape[0], -1))
predictions = scaler.inverse_transform(predictions.reshape(-1, 1))
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")

last_observed = X_test[-1].reshape(1, -1)
forecast_value = model.predict(last_observed)
forecast_value = scaler.inverse_transform(forecast_value.reshape(-1, 1))[0][0]
print(f"Forecast for PolyPwr (Yn+1): {forecast_value:.2f}")
# Out:
# Root Mean Squared Error (RMSE): 5.16
# Forecast for PolyPwr (Yn+1): 12.39

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

df = pd.read_csv('Pasion et al dataset.csv')
data = df[df['Location'] == 'Hill Weber']
data = df[df['Time'] == 1400]

data = data[['Date', 'PolyPwr']] 
data.rename(columns={'Date': 'ds', 'PolyPwr': 'y'}, inplace=True)

data['ds'] = pd.to_datetime(data['ds'])
data.set_index('ds', inplace=True)

scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

look_back = 20  
X, y = [], []
for i in range(len(data_scaled) - look_back):
    X.append(data_scaled[i:i+look_back])
    y.append(data_scaled[i+look_back])

X, y = np.array(X), np.array(y)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

model = RandomForestRegressor(n_estimators=100, max_depth=3, random_state=42)
model.fit(X_train.reshape(X_train.shape[0], -1), y_train.reshape(-1))

predictions = model.predict(X_test.reshape(X_test.shape[0], -1))
predictions = scaler.inverse_transform(predictions.reshape(-1, 1))
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")

last_observed = X_test[-1].reshape(1, -1)
forecast_value = model.predict(last_observed)
forecast_value = scaler.inverse_transform(forecast_value.reshape(-1, 1))[0][0]
print(f"Forecast for PolyPwr (Yn+1): {forecast_value:.2f}")
# Out:
# Root Mean Squared Error (RMSE): 5.27
# Forecast for PolyPwr (Yn+1): 14.31

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

df = pd.read_csv('Pasion et al dataset.csv')
data = df[df['Location'] == 'Hill Weber']
data = df[df['Time'] == 1500]

data = data[['Date', 'PolyPwr']] 
data.rename(columns={'Date': 'ds', 'PolyPwr': 'y'}, inplace=True)

data['ds'] = pd.to_datetime(data['ds'])
data.set_index('ds', inplace=True)

scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

look_back = 20  
X, y = [], []
for i in range(len(data_scaled) - look_back):
    X.append(data_scaled[i:i+look_back])
    y.append(data_scaled[i+look_back])

X, y = np.array(X), np.array(y)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

model = RandomForestRegressor(n_estimators=100, max_depth=3, random_state=42)
model.fit(X_train.reshape(X_train.shape[0], -1), y_train.reshape(-1))

predictions = model.predict(X_test.reshape(X_test.shape[0], -1))
predictions = scaler.inverse_transform(predictions.reshape(-1, 1))
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")

last_observed = X_test[-1].reshape(1, -1)
forecast_value = model.predict(last_observed)
forecast_value = scaler.inverse_transform(forecast_value.reshape(-1, 1))[0][0]
print(f"Forecast for PolyPwr (Yn+1): {forecast_value:.2f}")
# Out:
# Root Mean Squared Error (RMSE): 4.83
# Forecast for PolyPwr (Yn+1): 12.22
